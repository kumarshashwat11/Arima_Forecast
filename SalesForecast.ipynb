# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('salesdaily.csv')

# %%
df.head()
# Out:
#       datum  M01AB  M01AE  N02BA  N02BE  N05B  N05C   R03  R06  Year  Month  \
# 0  1/2/2014    0.0   3.67    3.4  32.40   7.0   0.0   0.0  2.0  2014      1
# 1  1/3/2014    8.0   4.00    4.4  50.60  16.0   0.0  20.0  4.0  2014      1
# 2  1/4/2014    2.0   1.00    6.5  61.85  10.0   0.0   9.0  1.0  2014      1
# 3  1/5/2014    4.0   3.00    7.0  41.10   8.0   0.0   3.0  0.0  2014      1
# 4  1/6/2014    5.0   1.00    4.5  21.70  16.0   2.0   6.0  2.0  2014      1
#
#    Hour Weekday Name
# 0   248     Thursday
# 1   276       Friday
# 2   276     Saturday
# 3   276       Sunday
# 4   276       Monday

# %%
df.tail()
# Out:
#           datum  M01AB   M01AE  N02BA  N02BE  N05B  N05C   R03   R06  Year  \
# 2101  10/4/2019   7.34   5.683   2.25  22.45  13.0   0.0   1.0  1.00  2019
# 2102  10/5/2019   3.84   5.010   6.00  25.40   7.0   0.0   0.0  0.33  2019
# 2103  10/6/2019   4.00  11.690   2.00  34.60   6.0   0.0   5.0  4.20  2019
# 2104  10/7/2019   7.34   4.507   3.00  50.80   6.0   0.0  10.0  1.00  2019
# 2105  10/8/2019   0.33   1.730   0.50  44.30  20.0   2.0   2.0  0.00  2019
#
#       Month  Hour Weekday Name
# 2101     10   276       Friday
# 2102     10   276     Saturday
# 2103     10   276       Sunday
# 2104     10   276       Monday
# 2105     10   190      Tuesday

# %%
df.drop(['Year','Month', 'Hour','Weekday Name'],axis=1,inplace=True)

# %%
df.shape
# Out:
# (2106, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2106 entries, 0 to 2105
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   datum   2106 non-null   object
#  1   M01AB   2106 non-null   float64
#  2   M01AE   2106 non-null   float64
#  3   N02BA   2106 non-null   float64
#  4   N02BE   2106 non-null   float64
#  5   N05B    2106 non-null   float64
#  6   N05C    2106 non-null   float64
#  7   R03     2106 non-null   float64
#  8   R06     2106 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 148.2+ KB

# %%
df.isnull().sum()
# Out:
# datum    0
# M01AB    0
# M01AE    0
# N02BA    0
# N02BE    0
# N05B     0
# N05C     0
# R03      0
# R06      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.nunique()
# Out:
# datum    2106
# M01AB     218
# M01AE     694
# N02BA     199
# N02BE     713
# N05B       77
# N05C       20
# R03        64
# R06        98
# dtype: int64

# %%
df.isna().sum()
# Out:
# datum    0
# M01AB    0
# M01AE    0
# N02BA    0
# N02BE    0
# N05B     0
# N05C     0
# R03      0
# R06      0
# dtype: int64

# %%
df["R03"].value_counts()
# Out:
# R03
# 0.000000     484
# 1.000000     257
# 5.000000     188
# 2.000000     173
# 6.000000     146
#             ...
# 15.416667      1
# 7.031250       1
# 3.125000       1
# 36.000000      1
# 1.416667       1
# Name: count, Length: 64, dtype: int64

# %%
df.rename(columns = {'datum':'date'}, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2106 entries, 0 to 2105
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    2106 non-null   object
#  1   M01AB   2106 non-null   float64
#  2   M01AE   2106 non-null   float64
#  3   N02BA   2106 non-null   float64
#  4   N02BE   2106 non-null   float64
#  5   N05B    2106 non-null   float64
#  6   N05C    2106 non-null   float64
#  7   R03     2106 non-null   float64
#  8   R06     2106 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 148.2+ KB

# %%
from datetime import datetime, date 

df['date'] = pd.to_datetime(df['date'],format='%m/%d/%Y')
df.head().style.set_properties(subset=['date'], **{'background-color': 'lightblue'})
# Out:
# <style type="text/css">
# #T_8f58f_row0_col0, #T_8f58f_row1_col0, #T_8f58f_row2_col0, #T_8f58f_row3_col0, #T_8f58f_row4_col0 {
#   background-color: lightblue;
# }
# </style>
# <table id="T_8f58f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8f58f_level0_col0" class="col_heading level0 col0" >date</th>
#       <th id="T_8f58f_level0_col1" class="col_heading level0 col1" >M01AB</th>
#       <th id="T_8f58f_level0_col2" class="col_heading level0 col2" >M01AE</th>
#       <th id="T_8f58f_level0_col3" class="col_heading level0 col3" >N02BA</th>
#       <th id="T_8f58f_level0_col4" class="col_heading level0 col4" >N02BE</th>
#       <th id="T_8f58f_level0_col5" class="col_heading level0 col5" >N05B</th>
#       <th id="T_8f58f_level0_col6" class="col_heading level0 col6" >N05C</th>
#       <th id="T_8f58f_level0_col7" class="col_heading level0 col7" >R03</th>
#       <th id="T_8f58f_level0_col8" class="col_heading level0 col8" >R06</th>
# ...

# %%
df['M01AB'].describe()
# Out:
# count    2106.000000
# mean        5.033683
# std         2.737579
# min         0.000000
# 25%         3.000000
# 50%         4.990000
# 75%         6.670000
# max        17.340000
# Name: M01AB, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
f, ax = plt.subplots(nrows=8, ncols=1, figsize=(15, 28))

for i, column in enumerate(df.drop('date', axis=1).columns):
    sns.lineplot(x=df['date'], y=df[column].fillna(method='ffill'), ax=ax[i], color='red')
    ax[i].set_title('Feature: {}'.format(column), fontsize=14)
    ax[i].set_ylabel(ylabel=column, fontsize=14)
                      
    ax[i].set_xlim([date(2014, 1, 2), date(2019, 10, 8)])
# Out:
# C:\Users\Siddhant Saurabh\AppData\Local\Temp\ipykernel_17304\4268073491.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   sns.lineplot(x=df['date'], y=df[column].fillna(method='ffill'), ax=ax[i], color='red')
# C:\Users\Siddhant Saurabh\AppData\Local\Temp\ipykernel_17304\4268073491.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   sns.lineplot(x=df['date'], y=df[column].fillna(method='ffill'), ax=ax[i], color='red')
# C:\Users\Siddhant Saurabh\AppData\Local\Temp\ipykernel_17304\4268073491.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   sns.lineplot(x=df['date'], y=df[column].fillna(method='ffill'), ax=ax[i], color='red')
# ...

# %%
df = df.sort_values(by='date')

# Check time intervals
df['delta'] = df['date'] - df['date'].shift(1)

df[['date', 'delta']].head()
# Out:
#         date  delta
# 0 2014-01-02    NaT
# 1 2014-01-03 1 days
# 2 2014-01-04 1 days
# 3 2014-01-05 1 days
# 4 2014-01-06 1 days

# %%
df[['date', 'delta']].tail()
# Out:
#            date  delta
# 2101 2019-10-04 1 days
# 2102 2019-10-05 1 days
# 2103 2019-10-06 1 days
# 2104 2019-10-07 1 days
# 2105 2019-10-08 1 days

# %%
df['delta'].sum(), df['delta'].count()
# Out:
# (Timedelta('2105 days 00:00:00'), 2105)

# %%
f, ax = plt.subplots(nrows=1, ncols=1, figsize=(16,5))

sns.heatmap(df.T.isna(), cmap='Blues', ax=ax)
ax.set_title('Missing Values', fontsize=16)

# for tick in ax.yaxis.get_major_ticks():
#     tick.label.set_fontsize(14)
plt.show()

# %%
# resampling data
fig, ax = plt.subplots(ncols=1, nrows=3, sharex=True, figsize=(16,12))

sns.lineplot(x=df['date'], y=df['M01AB'], color='dodgerblue', ax=ax[0])
ax[0].set_title('Daily M01AB Sales', fontsize=14)

resampled_df = df[['date','M01AB']].resample('7D', on='date').sum().reset_index(drop=False)
sns.lineplot(x=resampled_df['date'], y=resampled_df['M01AB'], color='dodgerblue', ax=ax[1])
ax[1].set_title('Weekly M01AB Sales', fontsize=14)

resampled_df = df[['date','M01AB']].resample('M', on='date').sum().reset_index(drop=False)
sns.lineplot(x=resampled_df['date'], y=resampled_df['M01AB'], color='dodgerblue', ax=ax[2])
ax[2].set_title('Monthly M01AB Sales', fontsize=14)

for i in range(3):
    ax[i].set_xlim([date(2014, 1, 2), date(2019, 10, 8)])
# Out:
# C:\Users\Siddhant Saurabh\AppData\Local\Temp\ipykernel_17304\2522777845.py:11: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   resampled_df = df[['date','M01AB']].resample('M', on='date').sum().reset_index(drop=False)

# %%
downsample = df[['date',
                 'M01AB','M01AE','N02BA','N02BE','N05B','N05C','R03','R06'
                ]].resample('7D', on='date').mean().reset_index(drop=False)

df1 = downsample.copy()

# %%
#Visual check for constant mean, constant variance on downsampled weekly data 
rolling_window = 52
f, ax = plt.subplots(nrows=1, ncols=1, figsize=(15, 6))

sns.lineplot(x=df1['date'], y=df['M01AB'], color='dodgerblue', ax=ax)
sns.lineplot(x=df1['date'], y=df['M01AB'].rolling(rolling_window).mean(),  color='black', label='rolling mean', ax=ax)
sns.lineplot(x=df1['date'], y=df['M01AB'].rolling(rolling_window).std(),  color='orange', label='rolling std', ax=ax)
ax.set_title('M01AB Sales: Non-stationary \nnon-constant mean & non-constant variance', fontsize=14)
ax.set_ylabel(ylabel='M01AB', fontsize=14)
ax.set_xlim([date(2014, 1, 2), date(2019, 10, 8)])
# Out:
# (16072.0, 18177.0)

# %%
from statsmodels.tsa.stattools import adfuller

# %%
adfuller(df1['M01AB'].values)
# Out:
# (-2.805405335944333,
#  0.057505792968277965,
#  8,
#  292,
#  {'1%': -3.4529449243622383,
#   '5%': -2.871489553425686,
#   '10%': -2.572071437887033},
#  850.8011180092171)

# %%
f, ax = plt.subplots(nrows=4, ncols=2, figsize=(15, 12))

def visualize_adfuller_results(series, title, ax):
    result = adfuller(series)
    significance_level = 0.05
    adf_stat = result[0]
    p_val = result[1]
    crit_val_1 = result[4]['1%']
    crit_val_5 = result[4]['5%']
    crit_val_10 = result[4]['10%']

    if (p_val < significance_level) & ((adf_stat < crit_val_1)):
        linecolor = 'forestgreen' 
    elif (p_val < significance_level) & (adf_stat < crit_val_5):
        linecolor = 'orange'
    elif (p_val < significance_level) & (adf_stat < crit_val_10):
        linecolor = 'red'
    else:
        linecolor = 'purple'
    sns.lineplot(x=df1['date'], y=series, ax=ax, color=linecolor)
    ax.set_title(f'ADF Statistic {adf_stat:0.3f}, p-value: {p_val:0.3f}\nCritical Values 1%: {crit_val_1:0.3f}, 5%: {crit_val_5:0.3f}, 10%: {crit_val_10:0.3f}', fontsize=14)
    ax.set_ylabel(ylabel=title, fontsize=14)

visualize_adfuller_results(df1['M01AB'].values, 'M01AB', ax[0, 0])
visualize_adfuller_results(df1['M01AE'].values, 'M01AE', ax[1, 0])
visualize_adfuller_results(df1['N02BA'].values, 'N02BA', ax[2, 0])
visualize_adfuller_results(df1['N02BE'].values, 'N02BE', ax[3, 0])
visualize_adfuller_results(df1['N05B'].values, 'N05B', ax[0, 1])
visualize_adfuller_results(df1['N05C'].values, 'N05C', ax[1, 1])
visualize_adfuller_results(df1['R03'].values, 'R03', ax[2, 1])
visualize_adfuller_results(df1['R06'].values, 'R06', ax[3, 1])

# %%
f,ax = plt.subplots(nrows=1, ncols=1, figsize=(20, 6))
visualize_adfuller_results(np.log(abs(df1['M01AB'])), 'Transformed \n Depth to Groundwater',ax)

# %%
f,ax = plt.subplots(nrows=1, ncols=1, figsize=(20, 6))
# M01AB_diff= np.diff(df1['M01AB'])
df1['M01AB_diff_1']=np.append([0], np.diff(df1['M01AB']))
visualize_adfuller_results(df1['M01AB_diff_1'], 'Transformed \n Depth to Groundwater',ax)

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

core_columns =  [    'M01AB','M01AE','N02BA','N02BE','N05B','N05C','R03','R06']

for column in core_columns:
    decomp = seasonal_decompose(df1[column], period=52, model='additive', extrapolate_trend='freq')
    df1[f"{column}_trend"] = decomp.trend
    df1[f"{column}_seasonal"] = decomp.seasonal

# %%
fig, ax = plt.subplots(ncols=2, nrows=4, sharex=True, figsize=(16,8))

for i, column in enumerate(['M01AB', 'M01AE']):
    
    res = seasonal_decompose(df1[column], period=52, model='additive', extrapolate_trend='freq')

    ax[0,i].set_title('Decomposition of {}'.format(column), fontsize=16)
    res.observed.plot(ax=ax[0,i], legend=False, color='dodgerblue')
    ax[0,i].set_ylabel('Observed', fontsize=14)

    res.trend.plot(ax=ax[1,i], legend=False, color='dodgerblue')
    ax[1,i].set_ylabel('Trend', fontsize=14)

    res.seasonal.plot(ax=ax[2,i], legend=False, color='dodgerblue')
    ax[2,i].set_ylabel('Seasonal', fontsize=14)
    
    res.resid.plot(ax=ax[3,i], legend=False, color='dodgerblue')
    ax[3,i].set_ylabel('Residual', fontsize=14)

plt.show()

# %%
f, ax = plt.subplots(nrows=8, ncols=1, figsize=(15, 16))
f.suptitle('Seasonal Components of Features', fontsize=16)

for i, column in enumerate(core_columns):
    sns.lineplot(x=df1['date'], y=df1[column + '_seasonal'], ax=ax[i], color='dodgerblue')
    ax[i].set_ylabel(ylabel=column, fontsize=14)
    ax[i].set_xlim([date(2014, 1, 2), date(2019, 10, 8)])
    
plt.tight_layout()
plt.show()

# %%
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(df1['M01AB_diff_1'])
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf

f, ax = plt.subplots(nrows=2, ncols=1, figsize=(16, 8))

plot_acf(df1['M01AB_diff_1'], lags=100, ax=ax[0])
plot_pacf(df1['M01AB_diff_1'], lags=100, ax=ax[1])

plt.show()

# %%
from sklearn.model_selection import TimeSeriesSplit

N_SPLITS = 4

X = df1['date']
y = df1['M01AB']

folds = TimeSeriesSplit(n_splits=N_SPLITS)

# %%
f, ax = plt.subplots(nrows=N_SPLITS, ncols=2, figsize=(16, 9))

for i, (train_index, valid_index) in enumerate(folds.split(X)):
    X_train, X_valid = X[train_index], X[valid_index]
    y_train, y_valid = y[train_index], y[valid_index]

    sns.lineplot(
        x=X_train, 
        y=y_train, 
        ax=ax[i,0], 
        color='dodgerblue', 
        label='train'
    )
    sns.lineplot(
        x=X_train[len(X_train) - len(X_valid):(len(X_train) - len(X_valid) + len(X_valid))], 
        y=y_train[len(X_train) - len(X_valid):(len(X_train) - len(X_valid) + len(X_valid))], 
        ax=ax[i,1], 
        color='dodgerblue', 
        label='train'
    )

    for j in range(2):
        sns.lineplot(x= X_valid, y= y_valid, ax=ax[i, j], color='darkorange', label='validation')
    ax[i, 0].set_title(f"Rolling Window with Adjusting Training Size (Split {i+1})", fontsize=16)
    ax[i, 1].set_title(f"Rolling Window with Constant Training Size (Split {i+1})", fontsize=16)

for i in range(N_SPLITS):
    ax[i, 0].set_xlim([date(2014, 1, 2), date(2019, 10, 8)])
    ax[i, 1].set_xlim([date(2014, 1, 2), date(2019, 10, 8)])
    
plt.tight_layout()
plt.show()

# %%
train_size = int(0.9 * len(df1))
test_size = len(df1) - train_size
print(train_size, test_size)

univariate_df = df1[['date', 'M01AB']].copy()
univariate_df.columns = ['ds', 'y']

train = univariate_df.iloc[:train_size, :]

x_train, y_train = pd.DataFrame(univariate_df.iloc[:train_size, 0]), pd.DataFrame(univariate_df.iloc[:train_size, 1])
x_valid, y_valid = pd.DataFrame(univariate_df.iloc[train_size:, 0]), pd.DataFrame(univariate_df.iloc[train_size:, 1])

print(len(train), len(x_valid))
# Out:
# 270 31
# 270 31

# %%
from statsmodels.tsa.arima.model import ARIMA

# Fit model
model = ARIMA(y_train, order=(1,1,1))
model_fit = model.fit()
# model_fit.summary()
# Prediction with ARIMA
y_pred = model_fit.forecast(steps = 31)
# se = model_fit.forecast(steps = 45).se_mean
# conf = model_fit.forecast(steps = 45).conf_int()

score_mae = mean_absolute_error(y_valid, y_pred)
score_rmse = math.sqrt(mean_squared_error(y_valid, y_pred))

print('RMSE: {}'.format(score_rmse))
print('MAE:',score_mae)
# Out:
# RMSE: 0.8736365235718284
# MAE: 0.7009612510546972

# %%
f, ax = plt.subplots(nrows=1,ncols=1,figsize=(15,6))

plot_predict(model_fit, 1, 299, alpha=0.05, ax=ax)
sns.lineplot(x=x_valid.index, y=y_valid['y'], ax=ax, color='orange', label='Ground truth') #navajowhite

ax.set_title(f'Prediction \n MAE: {score_mae:.2f}, RMSE: {score_rmse:.2f}', fontsize=14)
ax.set_xlabel(xlabel='Date', fontsize=14)
ax.set_ylabel(ylabel='M01AB_Sales', fontsize=14)

#ax.set_ylim(-35, -18)
plt.show()

# %%
model_fit.get_forecast(steps=46)
